# %% [markdown]
# ### Data Aanalysis for Diwali sales data(clickget)
#
# ### Steps in DA
# * Objective - Draw meaningfull insights and valuable information for forecasting(future predication) and decison making for bussiness growth
# * Data Collection - tabular format (rows,cols) - pandas
# * Data cleaning
# * EDA (Explotary Data Analysis)
# * Visualization (charts) and key information
# * Conclusion:Report

# %%
 pip install numpy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries or modules
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\klemp\Desktop\DataAanalyst (RCB)\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv",encoding='unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing & Apparel       2655
# Food                     2493
# Electronics & Gadgets    2087
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                      100
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
df.duplicated().sum() # number of duplicates are 8
# Out:
# np.int64(8)

# %%
len(df)
# Out:
# 11251

# %%
df.drop_duplicates(inplace=True)

# %%
len(df) #11251 - 8 = 11243
# Out:
# 11243

# %%
df.nunique()
# Out:
# User_ID             3755
# Cust_name           1250
# Product_ID          2351
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6584
# Status                 0
# unnamed1               0
# dtype: int64

# %%
# checking the states where we sell our productes
df['State'].value_counts()
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1523
# Karnataka           1305
# Delhi               1107
# Madhya Pradesh       923
# Andhra Pradesh       812
# Himachal Pradesh     608
# Kerala               453
# Haryana              451
# Bihar                433
# Gujarat              428
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: count, dtype: int64

# %%
# checking null values
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11243
# unnamed1            11243
# dtype: int64

# %%
# view null rows
df['Amount'].isna().sum()
# Out:
# np.int64(12)

# %%
# view null rows for amount cell
f1 = df['Amount'].isna()
df[f1]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
f2 = df['Product_Category']=="Auto"
df[f2]
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0     1002903  Sanskriti  P00125942      F     26-35   28               0
# 1     1000732     Kartik  P00110942      F     26-35   35               1
# 2     1001990      Bindu  P00118542      F     26-35   35               1
# 3     1001425     Sudevi  P00237842      M      0-17   16               0
# 4     1000588       Joni  P00057942      M     26-35   28               1
# ...       ...        ...        ...    ...       ...  ...             ...
# 2460  1001941      Gopal  P00259142      M     36-45   26               1
# 2461  1001202    Diwakar  P00277642      F     36-45   39               0
# 4588  1005642     Eplett  P00057542      F      0-17   13               0
# 4651  1004704    Manshul  P00085242      F     18-25   24               1
# 4687  1000157   Michelle  P00102042      F     36-45   41               1
#
#                State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
f2 = df['Product_Category']=="Footwear & Shoes"
df[f2]
# Out:
#       User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 81    1000154     Shami  P00306042      F     51-55   53               1
# 82    1000749  Flanagan  P00114342      F     36-45   37               1
# 83    1006040      Pond  P00271242      F     26-35   28               1
# 84    1001284   O'Brian  P00157142      M     46-50   50               0
# 85    1004269   Namrata  P00345242      F     36-45   40               0
# ...       ...       ...        ...    ...       ...  ...             ...
# 9460  1000911   Jaydeep  P00101342      M     51-55   55               1
# 9465  1003619  Harrigan  P00246942      F     51-55   51               0
# 9468  1003018      Rhea  P00346042      F     36-45   45               0
# 9474  1002748    Farhat  P00004142      F     26-35   31               0
# 9476  1003403   Abelman  P00022142      F     36-45   42               0
#
#               State      Zone  Occupation  Product_Category  Orders   Amount  \
# ...

# %%
# drop unwanted columns
df.drop(columns=['Status','unnamed1'],inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# drop rows where we have null values
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# * Done with unwanted columns and rows which has null values

# %% [markdown]
# #### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  object
#  2   Product_ID        11231 non-null  object
#  3   Gender            11231 non-null  object
#  4   Age Group         11231 non-null  object
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  object
#  8   Zone              11231 non-null  object
#  9   Occupation        11231 non-null  object
#  10  Product_Category  11231 non-null  object
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
# typecasting of columns
# Amount = float to int
df['Amount']=df['Amount'].astype('int32') #16 bits = 2 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11231 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11231 non-null  int64
#  1   Cust_name         11231 non-null  object
#  2   Product_ID        11231 non-null  object
#  3   Gender            11231 non-null  object
#  4   Age Group         11231 non-null  object
#  5   Age               11231 non-null  int64
#  6   Marital_Status    11231 non-null  int64
#  7   State             11231 non-null  object
#  8   Zone              11231 non-null  object
#  9   Occupation        11231 non-null  object
#  10  Product_Category  11231 non-null  object
#  11  Orders            11231 non-null  int64
#  12  Amount            11231 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
# to view the statical information 
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123100e+04  11231.000000    11231.000000  11231.000000  11231.000000
# mean   1.003004e+06     35.411985        0.419998      2.489093   9454.084676
# std    1.716055e+03     12.756116        0.493580      1.114880   5221.728074
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004428e+06     43.000000        1.000000      3.000000  12677.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.describe()[['Age','Marital_Status','Orders','Amount']]
# Out:
#                 Age  Marital_Status        Orders        Amount
# count  11231.000000    11231.000000  11231.000000  11231.000000
# mean      35.411985        0.419998      2.489093   9454.084676
# std       12.756116        0.493580      1.114880   5221.728074
# min       12.000000        0.000000      1.000000    188.000000
# 25%       27.000000        0.000000      2.000000   5443.000000
# 50%       33.000000        0.000000      2.000000   8109.000000
# 75%       43.000000        1.000000      3.000000  12677.500000
# max       92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# ### find out number of male and female customers
